# %%
from collections import deque
from functools import cache

# %% [markdown]
# ## Part 1

# %%
test = [
"...........",
".....###.#.",
".###.##..#.",
"..#.#...#..",
"....#.#....",
".##..S####.",
".##..#...#.",
".......##..",
".##.#.####.",
".##..##.##.",
"..........."  
]

# %%
def get_start(text):
    
    start = None
    
    for n, row in enumerate(text):
        if "S" in row:
            start = (n, row.index("S"))
            break
    
    return start

# %%
def get_positions(grid, start, max_steps):
    
    steps = 0
    q = deque([start])

    while steps < max_steps:
        temp = set()
        
        for _ in range(len(q)):

            row, col = q.popleft()

            for dr, dc in [(1,0),(0,1),(-1,0),(0,-1)]:

                next_row, next_col = row+dr, col+dc

                if (min(next_row,next_col) < 0 or
                    next_row >= len(grid) or
                    next_col >= len(grid[0])
                   or grid[next_row][next_col]=="#"):
                    continue

                temp.add((next_row, next_col))

        for pos in temp:
            q.append(pos)

        steps += 1
        
    return q

# %%
max_steps = 6

start = get_start(test)
q = get_positions(test,start, max_steps)
result = len(set(q))

assert result == 16

# %%
text = open("day_21.txt", "r").readlines()
text = [i.split("\n")[0] for i in text]

# %%
max_steps = 64

start = get_start(text)
q = get_positions(text,start, max_steps)
result = len(set(q))
result
# Out:
# 3615

# %% [markdown]
# ## Part 2

# %%
text = open("day_21.txt", "r").readlines()
text = [i.split("\n")[0] for i in text]

# %%
cnt = 0

for row in text:
    cnt += row.count("#")
    
free_field = len(text)*len(text[0])-cnt
free_field
# Out:
# 14739

# %%
grid = text*21
grid = [row*21 for row in grid]

# %%
start = [len(grid)//2, len(grid[0])//2]
grid[start[0]][start[1]]
# Out:
# 'S'

# %%
grid[1375-66-130]
# Out:
# '.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
max_steps = (5*131)+65

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

# %%
print(f"odd")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375-65) <= row <= (1375+65) and (1375-65) <= col <= (1375+65):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
print(f"even")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375-65) <= row <= (1375+65) and (1375+65) <= col <= (1375+65+131):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
print(f"even: {max_steps % 2}")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375-65) <= row <= (1375+65) and (1375-65) <= col <= (1375+65):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
print(f"even: {max_steps % 2 + 1}")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375+65+1) <= row <= (1375+65+1+131) and (1375-65) <= col <= (1375+65):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
print(f"even: {max_steps % 2}")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375-65) <= row <= (1375+65) and (1375-65) <= col <= (1375+65):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
7354+7428

# %%
grid[1375+65]

# %%
len(grid[1375-65:1375+66])

# %%
max_steps = (5*131)+66

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

print(f"even: {max_steps % 2}")

cnt_box_1 = 0

for row, col in set(q):
    
    if (1375-65) <= row <= (1375+65) and (1375-65) <= col <= (1375+65):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
7362+7354

# %%
divmod(26501365,131)

# %%
(202300*202300)-((202300-1)*(202300-1))

# %%
404599*7354+((202300-1)*(202300-1)*(7354+7362))

# %%
p2 = ((n+1)*(n*1)) * odd_full + (n*n) * even_full - (n+1) * odd_corners + n * even_corners

# %%
n = 202300

# %%
((n+1)*(n+1)) * 7354 + (n*n) * 7428 - (n+1) * 6591 + n * 992

# %%
# 992
# 6591

# %%
#falsch 602259189649308
# falsch 602256924288309

# %%
start[0]-65-131-131-131-131-131

# %%
start

# %%
cnt_box_1 = 0

for row, col in set(q):
    
    if (655+131+131) <= row <= (655+131+131+131) and (1375-65-131-131) <= col <= (1375-65-131):
        cnt_box_1 += 1
print(cnt_box_1)

# %%
max_steps = (5*131)+65

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

# %%
7354+7362

# %%
grid[1375+65]

# %%
grid = test*21
grid = [row*21 for row in grid]

# %%
start = [len(grid)//2, len(grid[0])//2]

# %%
grid[start[0]][start[1]]

# %%
max_steps = 6

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 16

# %%
max_steps = 10

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 50

# %%
grid

# %%
len(test)*len(test[0])

# %%
cnt = 0

for row in test:
    cnt += row.count("#")
    
free_field = len(test)*len(test[0])-cnt
free_field

# %%
start

# %%
grid[110]

# %%
grid[120]

# %%
cnt_box_1 = 0

for row, col in set(q):
    
    if 110 <= row <= 120 and 110 <= col <= 120:
        cnt_box_1 += 1

# %%
cnt_box_1

# %%
len(set(q))

# %%
grid[99]

# %%
grid[131]

# %%
max_steps = 102

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

# assert result == 6536

# %%
cnt_box_1 = 0

for row, col in set(q):
    
    if 99 <= row <= 131 and 99 <= col <= 131:
        cnt_box_1 += 1

# %%
cnt_box_1

# %%
cnt_box_1

# %%
cnt_box_1

# %%
grid[88]

# %%
grid[142]

# %%
max_steps = 202

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

# assert result == 6536

# %%
max_steps = 50

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 1594

# %%
max_steps = 100

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 6536

# %%
start

# %%
grid[110]

# %%
grid[120]

# %%
cnt_box_1 = 0

for row, col in set(q):
    
    if 110 <= row <= 120 and 110 <= col <= 120:
        cnt_box_1 += 1

# %%
cnt_box_1

# %%
len(set(q))

# %%
max_steps = 103

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 6536

# %%
cnt_box_1 = 0

for row, col in set(q):
    
    if 110 <= row <= 120 and 110 <= col <= 120:
        cnt_box_1 += 1

# %%
cnt_box_1

# %%
max_steps = 500

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 167004

# %%
max_steps = 1000

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 668697

# %%
max_steps = 5000

# start = get_start(test)
q = get_positions(grid,start, max_steps)
result = len(set(q))

assert result == 16733044

# %%
import numpy as np

# %%
x = np.array([0, 6, 10, 50, 100,  500,  1000, 5000])
y = np.array([0, 16, 50, 1594, 6536, 167004, 668697, 16733044])
z = np.polyfit(x, y, 3)
p = np.poly1d(z)

# %%
p(26501365)

# %%
p(26501365)

# %%
557886915186746.3 > 470183123321326.0
