# %% [markdown]
# ## Part 1

# %%
test = [
"O....#....",
"O.OO#....#",
".....##...",
"OO.#O....O",
".O.....O#.",
"O.#..O.#.#",
"..O..#O..O",
".......O..",
"#....###..",
"#OO..#...."
]

# %%
grid = ["".join(reversed(x)) for x in zip(*test)]
grid = [["".join(sorted(j)) for j in i.split("#")] for i in grid]
grid = ["#".join(i) for i in grid]

# %%
results = []

for row in grid:
    result = [n for n,i in enumerate(row,1) if i == "O"]
    results.append(sum(result))

# %%
assert sum(results)== 136

# %%
text = open("day_14.txt", "r").readlines()
text = [i.split("\n")[0] for i in text]

# %%
grid = ["".join(reversed(x)) for x in zip(*text)]
grid = [["".join(sorted(j)) for j in i.split("#")] for i in grid]
grid = ["#".join(i) for i in grid]

# %%
results = []

for row in grid:
    result = [n for n,i in enumerate(row,1) if i == "O"]
    results.append(sum(result))

# %%
sum(results)
# Out:
# 110821

# %% [markdown]
# ## Part 2

# %%
from functools import cache

# %%
grid = [
"O....#....",
"O.OO#....#",
".....##...",
"OO.#O....O",
".O.....O#.",
"O.#..O.#.#",
"..O..#O..O",
".......O..",
"#....###..",
"#OO..#...."
]

# %%
def calculate_results(grid):
    
    grid = ["".join(reversed(x)) for x in zip(*grid)]
    
    results = []

    for row in grid:
        result = [n for n,i in enumerate(row,1) if i == "O"]
        results.append(sum(result))
        
    return results

# %%
@cache
def cycle_grid(grid):

    for _ in ["north", "west", "south", "east"]:

        grid = ["".join(reversed(x)) for x in zip(*grid)]
        grid = [["".join(sorted(j)) for j in i.split("#")] for i in grid]
        grid = ["#".join(i) for i in grid]
        
    return grid

# %%
def get_cycle(grids):
    
    for i in range(len(grids)-1):
        for j in range(i+1, len(grids)):
            if grids[i] == grids[j]:
                return i,j
            
    return None

# %%
store_cycle = []
found_cycle = False
i = 0

while not found_cycle:
        i += 1
        
        grid = cycle_grid(tuple(grid))
        
        if grid in store_cycle:
            store_cycle.append(grid)
            break
        store_cycle.append(grid)

# %%
start,end = get_cycle(store_cycle)

# %%
idx = ((1000000000 - start) % (end-start))

# %%
assert sum(calculate_results(store_cycle[start + idx-1])) == 64

# %%
text = open("day_14.txt", "r").readlines()
grid = [i.split("\n")[0] for i in text]

# %%
store_cycle = []
found_cycle = False
i = 0

while not found_cycle:
        i += 1
        
        grid = cycle_grid(tuple(grid))
        
        if grid in store_cycle:
            store_cycle.append(grid)
            break
        store_cycle.append(grid)

# %%
start,end = get_cycle(store_cycle)

# %%
idx = (1000000000 - start) % (end-start)

# %%
sum(calculate_results(store_cycle[start + idx-1]))
# Out:
# 83516
