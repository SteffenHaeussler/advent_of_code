# %% [markdown]
# ## Day 3

# %% [markdown]
# ### Test

# %%
test = """987654321111111
811111111111119
234234234234278
818181911112111
"""

# %%
test = test.split("\n")[:-1]

# %%
def get_jolt(seq, n=12):

    seq = ""
    cur = 0
    
    while len(seq) < n:
    
        split = len(rating) - n + len(seq) + 1
        
        temp = rating[cur:split]
        
        max_val = max(temp)
        idx = temp.index(max_val)
        
        seq += max_val
        cur += idx +1   

    return seq

# %%
jolts = []

for rating in test:

    jolt = get_jolt(rating, 2)
    
    jolts.append(int(jolt))

# %%
result = sum(jolts)

# %%
assert result == 357

# %% [markdown]
# ## Part 1

# %%
with open("../../../advent_of_code_input/2025/day_3/input.txt", "r") as f:
    data = f.read()

# %%
data = data.split("\n")[:-1]

# %%
jolts = []

for rating in data:

    jolt = get_jolt(rating, 2)
    
    jolts.append(int(jolt))

# %%
result = sum(jolts)
result
# Out:
# 17263

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Test

# %%
test = """987654321111111
811111111111119
234234234234278
818181911112111
"""

# %%
test = test.split("\n")[:-1]

# %%
jolts = []

for rating in test:

    jolt = get_jolt(rating)
    
    jolts.append(int(jolt))

# %%
assert sum(jolts) == 3121910778619

# %% [markdown]
# ## Puzzle

# %%
with open("../../../advent_of_code_input/2025/day_3/input.txt", "r") as f:
    data = f.read()

# %%
data = data.split("\n")[:-1]

# %%
jolts = []

for rating in data:

    jolt = get_jolt(rating)
    
    jolts.append(int(jolt))

# %%
result = sum(jolts)
result
# Out:
# 170731717900423
